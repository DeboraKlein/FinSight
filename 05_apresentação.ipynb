# %% [markdown]
# Apresentação Executiva (Business Case)O foco da apresentação é convencer a diretoria de que o projeto deve ser financiado e implementado, destacando o Retorno Ajustado ao Risco (RAROC) obtido.SLIDE 1: Título e Tese CentralTítuloModelo Preditivo de Intervenção ProativaSubtítuloMaximizando o RAROC: Convertendo Risco de Rotativo em Ativo de Crédito PessoalTeseIntervir no Estresse Agudo do cliente (probabilidade $\ge 0.20$) com oferta de consolidação (crédito pessoal) para mitigar perdas e garantir fidelização.SLIDE 2: O Problema e a SoluçãoSeçãoO Problema Atual (Custo de Esperar)Nossa Solução (Valor da Antecipação)Dor FinanceiraClientes entrando no Rotativo (custo altíssimo) $\rightarrow$ Risco elevado de Perda (PDD) e Inadimplência.Intervenção antes do default (Threshold 0.20), oferecendo uma solução de dívida mais barata (Empréstimo Pessoal).ModeloAbordagens reativas (Score Serasa/SPC).LightGBM otimizado para $Recall$ (89%), focando em features de tendência de 3 meses (sinais de estresse).ImpactoPerda de capital, alta provisão (IFRS 9 / PECLD Estágio 2).Aumento da Receita Sustentável e redução do Capital Econômico (UL).SLIDE 3: Performance e Otimização FinanceiraEste slide é o coração técnico e financeiro.MétricaValor Final Validado (OOT)Interpretação de NegócioPoder Preditivo ($AUC$)0.7281Discriminação robusta em validação cronológica (Out-of-Time).Threshold Otimizado0.20Ponto de corte que maximiza o Retorno Ajustado ao Risco (RAROC).Recall (Mitigação de Risco)89%VITÓRIA DO NEGÓCIO: Identificamos e permitimos salvar 9 em cada 10 clientes que iriam para o rotativo.SLIDE 4: O Trade-Off Estratégico (O Custo Que Virou Oportunidade)MétricaValorConsequênciaEstratégia de Negócio$Precision$32%68% dos alertas são Falsos Positivos (clientes que não iriam para o rotativo).Intervenção Consultiva: Usamos o alerta para oferecer uma vantagem (crédito mais barato) a clientes seguros, gerando Lealdade e Fidelização.AçãoCusto Operacional (SAC, Gerentes).Investimento em Relacionamento: A abordagem amigável ("Proposta de Otimização Financeira") anula a insatisfação e aumenta o engajamento.SLIDE 5: Estrutura de Operacionalização (Fluxo de Valor)Este slide deve mostrar como o time de atendimento usa o modelo.Fluxo de Decisão:Pipeline MLOps: Modelo roda diariamente, gerando $y\_proba$.Decisão de Negócio: Aplica a regra de $y\_proba \ge 0.20$.Encaminhamento Otimizado:$y\_proba \ge 0.50$ (Risco Crítico) $\rightarrow$ Gerente de Carteira/Telefone (Alto Toque).$0.20 \le y\_proba < 0.50$ (Risco Moderado) $\rightarrow$ Canais Digitais (Escala, Oferta Amigável Automatizada).Mensagem Chave para a Equipe: "O alerta não é sobre cobrança; é sobre a proposta de valor da FinTech para a saúde financeira do cliente."SLIDE 6: Próximos Passos e Chamada para AçãoValidação em Campo (MVP): Lançar a intervenção em um grupo de clientes (piloto) para medir o impacto direto na taxa de default e na aceitação da oferta.MLOps Final: Finalizar a integração com os sistemas de real-time e configurar o monitoramento de $AUC$ e Feature Drift.Conclusão: O projeto está Pronto para o MVP, com risco financeiro quantificado e uma estratégia de intervenção que garante a sustentabilidade e o crescimento da carteira.
